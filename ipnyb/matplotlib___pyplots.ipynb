# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np_random_randint__x_1 = np.random.randint(10, size=5)
np_random_randint__y_1 = np.random.randint(10, size=5)
np_random_randint__x_2 = np.random.randint(10, size=6)
np_random_randint__y_2 = np.random.randint(10, size=6)
print(np_random_randint__x_1)

plt.plot(np_random_randint__x_1, np_random_randint__y_1, np_random_randint__x_2, np_random_randint__y_2,  "o:r")
plt.show()
plt.bar(np_random_randint__x_2, np_random_randint__y_2,)
plt.grid()
# Out:
# [4 5 2 4 1]
