# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np_random_randint__x_1 = np.random.randint(100, size=5)
np_random_randint__y_1 = np.random.randint(100, size=5)
np_random_randint__x_2 = np.random.randint(100, size=5)
np_random_randint__y_2 = np.random.randint(100, size=5)
print(np_random_randint__x_1)

plt.plot(np_random_randint__x_1, np_random_randint__y_1, np_random_randint__x_2, np_random_randint__y_2,  "o:r")
plt.bar(np_random_randint__x_1, np_random_randint__y_1,)
plt.show()
plt.grid()
# Out:
# [26 95 52 84 18]
